# %%
import pandas as pd
import numpy as np

# %%
true=pd.read_csv('/content/drive/MyDrive/All Datasets/True.csv')

# %%
fake=pd.read_csv('/content/drive/MyDrive/All Datasets/Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']=1

# %%
fake['label']=0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news=pd.concat([true,fake],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news.tail()
# Out:
#                                                    title  \
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23476  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...  Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 23479  21st Century Wire says Al Jazeera America will...  Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                    date  label
# 23476  January 16, 2016      0
# 23477  January 16, 2016      0
# 23478  January 15, 2016      0
# 23479  January 14, 2016      0
# 23480  January 12, 2016      0

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news=news.drop(['title','subject','date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  WASHINGTON (Reuters) - The head of a conservat...      1
# 1  WASHINGTON (Reuters) - Transgender people will...      1
# 2  WASHINGTON (Reuters) - The special counsel inv...      1
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...      1
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...      1

# %%
news=news.sample(frac=1)        #Reshuffling

# %%
news.head()
# Out:
#                                                     text  label
# 8284   WASHINGTON/NEW YORK (Reuters) - Hillary Clinto...      1
# 7771   (Reuters) - A federal judge in Phoenix will he...      1
# 14837  BUCHAREST (Reuters) - Romania has expelled a p...      1
# 22250  Liberals still don t get it. Trump is the poli...      0
# 770    BEIJING (Reuters) - China’s foreign ministry o...      1

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text  label
# 0   8284  WASHINGTON/NEW YORK (Reuters) - Hillary Clinto...      1
# 1   7771  (Reuters) - A federal judge in Phoenix will he...      1
# 2  14837  BUCHAREST (Reuters) - Romania has expelled a p...      1
# 3  22250  Liberals still don t get it. Trump is the poli...      0
# 4    770  BEIJING (Reuters) - China’s foreign ministry o...      1

# %%
news.drop(['index'],axis=1,inplace=True)

# %%
news.head()
# Out:
#                                                 text  label
# 0  WASHINGTON/NEW YORK (Reuters) - Hillary Clinto...      1
# 1  (Reuters) - A federal judge in Phoenix will he...      1
# 2  BUCHAREST (Reuters) - Romania has expelled a p...      1
# 3  Liberals still don t get it. Trump is the poli...      0
# 4  BEIJING (Reuters) - China’s foreign ministry o...      1

# %%
import re

# %%
def wordopt(text):
  #convert into lowercase
  text=text.lower()
  #Remove the URLs
  text=re.sub(r'https?://S+|www\.\S+','',text)

  #Remove the HTML tags
  text=re.sub(r'<.*?>','',text)

  #Remove punctuation
  text=re.sub(r'[^\w\s]','',text)

  #Remove digits
  text=re.sub(r'\d','',text)

  #Remove newline characters
  text=re.sub(r'\n',' ',text)

  return text

# %%
 #that wordopt apply to my text data
 news['text']=news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        washingtonnew york reuters  hillary clinton sa...
# 1        reuters  a federal judge in phoenix will hear ...
# 2        bucharest reuters  romania has expelled a pror...
# 3        liberals still don t get it trump is the polit...
# 4        beijing reuters  chinas foreign ministry on we...
#                                ...
# 44893    since donald trump won the electoral college v...
# 44894    san francisco reuters  the electronic frontier...
# 44895    rep adam schiff the ranking democrat on the ho...
# 44896    a nervous nancy pelosi responded thursday to c...
# 44897    how many more symptoms need to be uncovered be...
# Name: text, Length: 44898, dtype: object

# %%
x=news['text']
y=news['label']

# %%
x
# Out:
# 0        washingtonnew york reuters  hillary clinton sa...
# 1        reuters  a federal judge in phoenix will hear ...
# 2        bucharest reuters  romania has expelled a pror...
# 3        liberals still don t get it trump is the polit...
# 4        beijing reuters  chinas foreign ministry on we...
#                                ...
# 44893    since donald trump won the electoral college v...
# 44894    san francisco reuters  the electronic frontier...
# 44895    rep adam schiff the ranking democrat on the ho...
# 44896    a nervous nancy pelosi responded thursday to c...
# 44897    how many more symptoms need to be uncovered be...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 44893    0
# 44894    1
# 44895    0
# 44896    0
# 44897    0
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <31428x177221 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6465049 stored elements in Compressed Sparse Row format>

# %%
xv_test
# Out:
# <13470x177221 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2718934 stored elements in Compressed Sparse Row format>

# %% [markdown]
# **Creating ML Models**

# %% [markdown]
# # **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test,y_test)
# Out:
# 0.9888641425389755

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6988
#            1       0.99      0.99      0.99      6482
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %% [markdown]
# # **Decison Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
DTC = DecisionTreeClassifier()
DTC.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test,y_test)
# Out:
# 0.9960653303637713

# %%
print(classification_report(y_test,pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6988
#            1       1.00      0.99      1.00      6482
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %% [markdown]
# # Ensemble learning

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(xv_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rfc = rfc.predict(xv_test)

# %%
rfc.score(xv_test,y_test)
# Out:
# 0.987305122494432

# %%
print(classification_report(y_test,predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6988
#            1       0.99      0.99      0.99      6482
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %% [markdown]
# # **Gradient Boosting**

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
gbc.fit(xv_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gbc = gbc.predict(xv_test)

# %%
gbc.score(xv_test,y_test)
# Out:
# 0.9945063103192279

# %%
print(classification_report(y_test,pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      6988
#            1       0.99      1.00      0.99      6482
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
def output_label(n):
  if n == 0:
    return "Fake News"
  elif n == 1:
    return "True News"

# %% [markdown]
# # **Testing**

# %%
def manual_testing(news):
    testing_news = {"text": [news]}
    new_def_test = pd.DataFrame(testing_news)

    # Corrected this line to use 'new_def_test' instead of 'new_def'
    new_def_test["text"] = new_def_test['text'].apply(wordopt)

    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)

    pred_lr = LR.predict(new_xv_test)
    pred_gbc = gbc.predict(new_xv_test)
    pred_rfc = rfc.predict(new_xv_test)

    return "\n\nLR Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(
        output_label(pred_lr[0]),
        output_label(pred_gbc[0]),
        output_label(pred_rfc[0])
    )

# %%
news_article = str(input())
# Out:
# WASHINGTON (Reuters) - A federal judge in Seattle partially blocked U.S. President Donald Trumpâ€™s newest restrictions on refugee admissions on Saturday, the latest legal defeat for his efforts to curtail immigration and travel to the United States. The decision by U.S. District Judge James Robart is the first judicial curb on rules the Trump administration put into place in late October that have contributed significantly to a precipitous drop in the number of refugees being admitted into the country. Refugees and groups that assist them argued in court that the administrationâ€™s policies violated the Constitution and federal rulemaking procedures, among other claims. Department of Justice attorneys argued in part that U.S. law grants the executive branch the authority to limit refugee admissions in the way that it had done so. On Oct. 24, the Trump administration effectively paused refugee admissions from 11 countries mostly in the Middle East and Africa, pending a 90-day security review, which was set to expire in late January. The countries subject to the review